# %%
import sys
sys.path.append("/media/hdd/viscent/SR-UNet")
from utils.inference_utils import *

# %%
dhcp_train_loader, dhcp_test_loader, dhcp_val_loader = get_dataloader('dhcp',50,modality='t2')
hcp_train_loader, hcp_test_loader, hcp_val_loader = get_dataloader('hcp',50,modality='t2')
# Out:
# [11/24/22 18:00:11] INFO     colossalai - root - INFO: Creating dataset with 40 examples
#                     INFO     colossalai - root - INFO: length of list_images_t1: 40
#   0%|          | 0/40 [00:00<?, ?it/s]
# [11/24/22 18:00:24] INFO     colossalai - root - INFO: Creating dataset with 10 examples
#                     INFO     colossalai - root - INFO: length of list_images_t1: 10
#   0%|          | 0/10 [00:00<?, ?it/s]
# [11/24/22 18:00:27] INFO     colossalai - root - INFO: Creating dataset with 40 examples
#   0%|          | 0/40 [00:00<?, ?it/s]
# [11/24/22 18:00:34] INFO     colossalai - root - INFO: Creating dataset with 10 examples
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
display_multiplanar_center(iter(hcp_train_loader).next()[0][0,0])
display_multiplanar_center(iter(hcp_train_loader).next()[1][0,0])
